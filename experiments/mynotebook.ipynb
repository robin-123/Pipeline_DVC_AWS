# %% [markdown]
# ## Basic Imports

# %%
# Importing necessary libraries
import matplotlib
import numpy as np        # For numerical operations
import pandas as pd       # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
# %matplotlib inline

# Importing WordCloud for text visualization
from wordcloud import WordCloud

# Importing NLTK for natural language processing
import nltk
from nltk.corpus import stopwords    # For stopwords


# Downloading NLTK data
nltk.download('stopwords')   # Downloading stopwords data
nltk.download('punkt')       # Downloading tokenizer data
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Read the CSV file
df = pd.read_csv('spam.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace = True)
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Rename the columns name
df.rename(columns = {'v1': 'target', 'v2': 'text'}, inplace = True)
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])

df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#%pip install scikit-learn

# %%
#check duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
len(df)
# Out:
# 5572

# %%
#remove Duplicate
df = df.drop_duplicates(keep = 'first')
len(df)
# Out:
# 5169

# %% [markdown]
# ## Feature Engg

# %%
# Importing the Porter Stemmer for text stemming
from nltk.stem.porter import PorterStemmer

# Importing the string module for handling special characters
import string

# Creating an instance of the Porter Stemmer
ps = PorterStemmer()

# %%
# Lowercase transformation and text preprocessing function
def transform_text(text):
    # Transform the text to lowercase
    text = text.lower()
    
    # Tokenization using NLTK
    text = nltk.word_tokenize(text)
    
    # Removing special characters
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
            
    # Removing stop words and punctuation
    text = y[:]
    y.clear()
    
    # Loop through the tokens and remove stopwords and punctuation
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
        
    # Stemming using Porter Stemmer
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    
    # Join the processed tokens back into a single string
    return " ".join(y)

# %%
transform_text('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 transform_text('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
#
# Cell In[16], line 7, in transform_text(text)
#       4 text = text.lower()
#       6 # Tokenization using NLTK
# ----> 7 text = nltk.word_tokenize(text)
#       9 # Removing special characters
#      10 y = []
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\user/nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\share\\nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\lib\\nltk_data'
#     - 'C:\\Users\\user\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
df['transformed_text'] = df['text'].apply(transform_text)
df.head()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['transformed_text'] = df['text'].apply(transform_text)
#       2 df.head()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[16], line 7, in transform_text(text)
#       4 text = text.lower()
#       6 # Tokenization using NLTK
# ----> 7 text = nltk.word_tokenize(text)
#       9 # Removing special characters
#      10 y = []
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\user/nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\share\\nltk_data'
#     - 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python39\\lib\\nltk_data'
#     - 'C:\\Users\\user\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
tfid = TfidfVectorizer(max_features = 500)

# %%
#%pip install dvclive
from dvclive import Live
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting dvclive
#   Using cached dvclive-3.48.2-py3-none-any.whl.metadata (10 kB)
# Collecting dvc>=3.48.4 (from dvclive)
#   Using cached dvc-3.60.1-py3-none-any.whl.metadata (17 kB)
# Collecting dvc-render<2,>=1.0.0 (from dvclive)
#   Using cached dvc_render-1.0.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dvc-studio-client<1,>=0.20 (from dvclive)
#   Using cached dvc_studio_client-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: funcy in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvclive) (2.0)
# Collecting gto (from dvclive)
#   Using cached gto-1.7.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: ruamel.yaml in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvclive) (0.17.32)
# Collecting scmrepo<4,>=3 (from dvclive)
#   Using cached scmrepo-3.3.11-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: psutil in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvclive) (5.9.5)
# Collecting pynvml (from dvclive)
#   Using cached pynvml-12.0.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: dulwich in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-studio-client<1,>=0.20->dvclive) (0.21.5)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-studio-client<1,>=0.20->dvclive) (2.31.0)
# Requirement already satisfied: voluptuous in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-studio-client<1,>=0.20->dvclive) (0.13.1)
# Requirement already satisfied: gitpython>3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (3.1.31)
# Collecting dulwich (from dvc-studio-client<1,>=0.20->dvclive)
#   Downloading dulwich-0.23.1-cp39-cp39-win_amd64.whl.metadata (5.2 kB)
# Collecting pygit2>=1.14.0 (from scmrepo<4,>=3->dvclive)
#   Downloading pygit2-1.15.1-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pygtrie>=2.3.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (2.5.0)
# Collecting fsspec>=2024.2.0 (from fsspec[tqdm]>=2024.2.0->scmrepo<4,>=3->dvclive)
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (0.11.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (2.13.2)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (2.8.3)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from scmrepo<4,>=3->dvclive) (4.65.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvclive) (41.0.1)
# Requirement already satisfied: typing-extensions>=3.6 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvclive) (4.12.2)
# Requirement already satisfied: aiohttp in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (3.8.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cryptography>=3.1->asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvclive) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.12->cryptography>=3.1->asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvclive) (2.21)
# Requirement already satisfied: urllib3>=1.25 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dulwich->dvc-studio-client<1,>=0.20->dvclive) (1.26.16)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (23.1.0)
# Requirement already satisfied: celery in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (5.3.1)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.4.6)
# Collecting configobj>=5.0.9 (from dvc>=3.48.4->dvclive)
#   Using cached configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: distro>=1.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (1.8.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (2.1.6)
# Collecting dvc-data<3.17,>=3.16.2 (from dvc>=3.48.4->dvclive)
#   Using cached dvc_data-3.16.10-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: dvc-http>=2.29.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (2.30.2)
# Requirement already satisfied: dvc-objects in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.23.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.3.0)
# Requirement already satisfied: flatten_dict<1,>=0.4.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.4.2)
# Collecting flufl.lock<9,>=8.1.0 (from dvc>=3.48.4->dvclive)
#   Using cached flufl_lock-8.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: grandalf<1,>=0.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.8)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.0.8)
# Requirement already satisfied: kombu in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (5.3.1)
# Requirement already satisfied: networkx>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (3.1)
# Requirement already satisfied: omegaconf in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (2.3.0)
# Requirement already satisfied: packaging>=19 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (24.2)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (3.8.0)
# Requirement already satisfied: pydot>=1.2.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (1.4.2)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (3.1.0)
# Requirement already satisfied: rich>=12 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (13.4.2)
# Requirement already satisfied: shortuuid>=0.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (1.0.11)
# Requirement already satisfied: shtab<2,>=1.3.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (1.6.2)
# Requirement already satisfied: tabulate>=0.8.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (0.11.8)
# Requirement already satisfied: zc.lockfile>=1.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc>=3.48.4->dvclive) (3.0.post1)
# Requirement already satisfied: dictdiffer>=0.8.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-data<3.17,>=3.16.2->dvc>=3.48.4->dvclive) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-data<3.17,>=3.16.2->dvc>=3.48.4->dvclive) (5.6.1)
# Collecting dvc-objects (from dvc>=3.48.4->dvclive)
#   Using cached dvc_objects-5.1.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting sqltrie<1,>=0.11.0 (from dvc-data<3.17,>=3.16.2->dvc>=3.48.4->dvclive)
#   Using cached sqltrie-0.11.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: orjson<4,>=3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-data<3.17,>=3.16.2->dvc>=3.48.4->dvclive) (3.10.18)
# Requirement already satisfied: pywin32>=225 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from dvc-task<1,>=0.3.0->dvc>=3.48.4->dvclive) (306)
# Requirement already satisfied: billiard<5.0,>=4.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (4.1.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (1.1.1)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (0.3.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (2023.3)
# Requirement already satisfied: vine<6.0,>=5.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from celery->dvc>=3.48.4->dvclive) (5.0.0)
# Requirement already satisfied: six<2.0,>=1.12 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from flatten_dict<1,>=0.4.1->dvc>=3.48.4->dvclive) (1.16.0)
# Requirement already satisfied: atpublic in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from flufl.lock<9,>=8.1.0->dvc>=3.48.4->dvclive) (4.0)
# Collecting entrypoints (from gto->dvclive)
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gto->dvclive) (2.10.3)
# Collecting semver>=2.13.0 (from gto->dvclive)
#   Using cached semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting typer>=0.4.1 (from gto->dvclive)
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from kombu->dvc>=3.48.4->dvclive) (5.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto->dvclive) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto->dvclive) (2.27.1)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\user\appdata\roaming\python\python39\site-packages (from click-repl>=0.2.0->celery->dvc>=3.48.4->dvclive) (3.0.51)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gitpython>3->scmrepo<4,>=3->dvclive) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3->dvclive) (5.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from hydra-core>=1.1->dvc>=3.48.4->dvclive) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from omegaconf->dvc>=3.48.4->dvclive) (6.0)
# Requirement already satisfied: appdirs in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from iterative-telemetry>=0.0.7->dvc>=3.48.4->dvclive) (1.4.4)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from iterative-telemetry>=0.0.7->dvc>=3.48.4->dvclive) (3.12.2)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc>=3.48.4->dvclive) (0.2.6)
# Collecting cffi>=1.12 (from cryptography>=3.1->asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvclive)
#   Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->dvc-studio-client<1,>=0.20->dvclive) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->dvc-studio-client<1,>=0.20->dvclive) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->dvc-studio-client<1,>=0.20->dvclive) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from rich>=12->dvc>=3.48.4->dvclive) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from rich>=12->dvc>=3.48.4->dvclive) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc>=3.48.4->dvclive) (0.1.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from ruamel.yaml->dvclive) (0.2.7)
# Collecting shellingham>=1.3.0 (from typer>=0.4.1->gto->dvclive)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from zc.lockfile>=1.2.1->dvc>=3.48.4->dvclive) (49.2.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3->dvclive) (1.3.1)
# Collecting nvidia-ml-py<13.0.0a0,>=12.0.0 (from pynvml->dvclive)
#   Using cached nvidia_ml_py-12.575.51-py3-none-any.whl.metadata (9.3 kB)
# Using cached dvclive-3.48.2-py3-none-any.whl (43 kB)
# Using cached dvc_render-1.0.2-py3-none-any.whl (22 kB)
# Using cached dvc_studio_client-0.21.0-py3-none-any.whl (16 kB)
# Using cached scmrepo-3.3.11-py3-none-any.whl (73 kB)
# Downloading dulwich-0.23.1-cp39-cp39-win_amd64.whl (696 kB)
#    ---------------------------------------- 0.0/696.1 kB ? eta -:--:--
#    ----------------------------- --------- 524.3/696.1 kB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 696.1/696.1 kB 2.1 MB/s eta 0:00:00
# Using cached dvc-3.60.1-py3-none-any.whl (458 kB)
# Using cached dvc_data-3.16.10-py3-none-any.whl (77 kB)
# Using cached dvc_objects-5.1.1-py3-none-any.whl (33 kB)
# Using cached flufl_lock-8.2.0-py3-none-any.whl (11 kB)
# Using cached gto-1.7.2-py3-none-any.whl (45 kB)
# Using cached sqltrie-0.11.2-py3-none-any.whl (17 kB)
# Using cached configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading pygit2-1.15.1-cp39-cp39-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.8 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl (181 kB)
# Using cached semver-3.0.4-py3-none-any.whl (17 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached pynvml-12.0.0-py3-none-any.whl (26 kB)
# Using cached nvidia_ml_py-12.575.51-py3-none-any.whl (47 kB)
# Installing collected packages: nvidia-ml-py, sqltrie, shellingham, semver, pynvml, fsspec, flufl.lock, entrypoints, dvc-render, dulwich, configobj, cffi, pygit2, dvc-studio-client, dvc-objects, typer, dvc-data, scmrepo, gto, dvc, dvclive
#
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    ----------------------------------------  0/21 [nvidia-ml-py]
#   Attempting uninstall: sqltrie
#    ----------------------------------------  0/21 [nvidia-ml-py]
#     Found existing installation: sqltrie 0.7.0
#    ----------------------------------------  0/21 [nvidia-ml-py]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#     Uninstalling sqltrie-0.7.0:
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#       Successfully uninstalled sqltrie-0.7.0
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    - --------------------------------------  1/21 [sqltrie]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    --- ------------------------------------  2/21 [shellingham]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ----- ----------------------------------  3/21 [semver]
#    ------- --------------------------------  4/21 [pynvml]
#    ------- --------------------------------  4/21 [pynvml]
#    ------- --------------------------------  4/21 [pynvml]
#    ------- --------------------------------  4/21 [pynvml]
#    ------- --------------------------------  4/21 [pynvml]
#    ------- --------------------------------  4/21 [pynvml]
#   Attempting uninstall: fsspec
#    ------- --------------------------------  4/21 [pynvml]
#     Found existing installation: fsspec 2023.6.0
#    ------- --------------------------------  4/21 [pynvml]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#     Uninstalling fsspec-2023.6.0:
#    --------- ------------------------------  5/21 [fsspec]
#       Successfully uninstalled fsspec-2023.6.0
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#    --------- ------------------------------  5/21 [fsspec]
#   Attempting uninstall: flufl.lock
#    --------- ------------------------------  5/21 [fsspec]
#     Found existing installation: flufl-lock 8.0.1
#    --------- ------------------------------  5/21 [fsspec]
#     Uninstalling flufl-lock-8.0.1:
#    --------- ------------------------------  5/21 [fsspec]
#       Successfully uninstalled flufl-lock-8.0.1
#    --------- ------------------------------  5/21 [fsspec]
#    ----------- ----------------------------  6/21 [flufl.lock]
#    ----------- ----------------------------  6/21 [flufl.lock]
#    ----------- ----------------------------  6/21 [flufl.lock]
#    ------------- --------------------------  7/21 [entrypoints]
#   Attempting uninstall: dvc-render
#    ------------- --------------------------  7/21 [entrypoints]
#     Found existing installation: dvc-render 0.5.3
#    ------------- --------------------------  7/21 [entrypoints]
#    --------------- ------------------------  8/21 [dvc-render]
#     Uninstalling dvc-render-0.5.3:
#    --------------- ------------------------  8/21 [dvc-render]
#       Successfully uninstalled dvc-render-0.5.3
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#    --------------- ------------------------  8/21 [dvc-render]
#   Attempting uninstall: dulwich
#    --------------- ------------------------  8/21 [dvc-render]
#     Found existing installation: dulwich 0.21.5
#    --------------- ------------------------  8/21 [dvc-render]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#     Uninstalling dulwich-0.21.5:
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#       Successfully uninstalled dulwich-0.21.5
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#    ----------------- ----------------------  9/21 [dulwich]
#   Attempting uninstall: configobj
#    ----------------- ----------------------  9/21 [dulwich]
#    ------------------- -------------------- 10/21 [configobj]
#     Found existing installation: configobj 5.0.8
#    ------------------- -------------------- 10/21 [configobj]
#     Uninstalling configobj-5.0.8:
#    ------------------- -------------------- 10/21 [configobj]
#       Successfully uninstalled configobj-5.0.8
#    ------------------- -------------------- 10/21 [configobj]
#    ------------------- -------------------- 10/21 [configobj]
#    ------------------- -------------------- 10/21 [configobj]
#   Attempting uninstall: cffi
#    ------------------- -------------------- 10/21 [configobj]
#     Found existing installation: cffi 1.15.1
#    ------------------- -------------------- 10/21 [configobj]
#     Uninstalling cffi-1.15.1:
#    ------------------- -------------------- 10/21 [configobj]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
#    -------------------- ------------------- 11/21 [cffi]
# ...
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    ------------------------------------ --- 19/21 [dvc]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    -------------------------------------- - 20/21 [dvclive]
#    ---------------------------------------- 21/21 [dvclive]
#
# Successfully installed cffi-1.17.1 configobj-5.0.9 dulwich-0.23.1 dvc-3.60.1 dvc-data-3.16.10 dvc-objects-5.1.1 dvc-render-1.0.2 dvc-studio-client-0.21.0 dvclive-3.48.2 entrypoints-0.4 flufl.lock-8.2.0 fsspec-2025.5.1 gto-1.7.2 nvidia-ml-py-12.575.51 pygit2-1.15.1 pynvml-12.0.0 scmrepo-3.3.11 semver-3.0.4 shellingham-1.5.4 sqltrie-0.11.2 typer-0.16.0

# %%
X = tfid.fit_transform(df['transformed_text']).toarray()
y = df['target'].values

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(X,y,test_size = 0.20, random_state = 2)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel= "sigmoid", gamma  = 1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth = 5)
lrc = LogisticRegression(solver = 'liblinear', penalty = 'l1')
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2 )
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbdt = GradientBoostingClassifier(n_estimators = 50, random_state = 2)    
xgb  = XGBClassifier(n_estimators = 50, random_state = 2)

# %%
clfs = {
    'SVC': svc,
    'KNN': knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'Adaboost': abc,
    'Bgc': bc,
    'ETC': etc,
    'GBDT': gbdt,
    'xgb': xgb
    
}

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score
def train_classifier(clfs, X_train, y_train, X_test, y_test):
    clfs.fit(X_train,y_train)
    y_pred = clfs.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    return accuracy , precision

# %%
accuracy_scores = []
precision_scores = []
for name , clfs in clfs.items():
    current_accuracy, current_precision = train_classifier(clfs, X_train, y_train, X_test, y_test)
    print()
    print("For: ", name)
    print("Accuracy: ", current_accuracy)
    print("Precision: ", current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For:  SVC
# Accuracy:  0.9661508704061895
# Precision:  0.9327731092436975
#
# For:  KNN
# Accuracy:  0.9274661508704062
# Precision:  1.0
#
# For:  NB
# Accuracy:  0.9709864603481625
# Precision:  0.9655172413793104
#
# For:  DT
# Accuracy:  0.9381044487427466
# Precision:  0.9021739130434783
#
# For:  LR
# Accuracy:  0.9632495164410058
# Precision:  0.9629629629629629
#
# For:  RF
# Accuracy:  0.971953578336557
# Precision:  0.943089430894309
#
# For:  Adaboost
# Accuracy:  0.9613152804642167
# Precision:  0.9375
#
# For:  Bgc
# Accuracy:  0.965183752417795
# Precision:  0.9180327868852459
#
# For:  ETC
# Accuracy:  0.9729206963249516
# Precision:  0.9296875
#
# For:  GBDT
# Accuracy:  0.9506769825918762
# Precision:  0.9393939393939394
#
# For:  xgb
# Accuracy:  0.9709864603481625
# Precision:  0.9576271186440678
